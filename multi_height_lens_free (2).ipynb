# %%
# !pip install diffractio
# Out:
# Collecting diffractio
#   Downloading diffractio-0.2.4-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffractio) (11.0.0)
# Collecting ipympl (from diffractio)
#   Downloading ipympl-0.9.4-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from diffractio) (7.7.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from diffractio) (2.10.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from diffractio) (4.10.0.84)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from diffractio) (2.2.2)
# Collecting py-pol (from diffractio)
#   Downloading py_pol-1.1.3-py2.py3-none-any.whl.metadata (15 kB)
# Collecting screeninfo (from diffractio)
#   Downloading screeninfo-0.8.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipympl->diffractio) (0.2.0)
# Requirement already satisfied: ipython<9 in /usr/local/lib/python3.10/dist-packages (from ipympl->diffractio) (7.34.0)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from ipympl->diffractio) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ipympl->diffractio) (1.26.4)
# Requirement already satisfied: traitlets<6 in /usr/local/lib/python3.10/dist-packages (from ipympl->diffractio) (5.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->diffractio) (5.5.6)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->diffractio) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->diffractio) (3.0.13)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->diffractio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->diffractio) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->diffractio) (2024.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from py-pol->diffractio) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from py-pol->diffractio) (5.24.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from py-pol->diffractio) (1.13.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->diffractio) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->diffractio) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl->diffractio) (75.1.0)
# Collecting jedi>=0.16 (from ipython<9->ipympl->diffractio)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl->diffractio) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl->diffractio) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl->diffractio) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl->diffractio) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl->diffractio) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl->diffractio) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl->diffractio) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.4.0->ipympl->diffractio) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.4.0->ipympl->diffractio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.4.0->ipympl->diffractio) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.4.0->ipympl->diffractio) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.4.0->ipympl->diffractio) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.4.0->ipympl->diffractio) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->diffractio) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->diffractio) (6.5.5)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->py-pol->diffractio) (9.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->py-pol->diffractio) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython<9->ipympl->diffractio) (0.8.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (3.1.4)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (7.16.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (0.21.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (1.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython<9->ipympl->diffractio) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl->diffractio) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (0.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (0.21.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (1.8.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->diffractio) (1.2.2)
# Downloading diffractio-0.2.4-py2.py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.3/187.3 kB 5.5 MB/s eta 0:00:00
# Downloading ipympl-0.9.4-py3-none-any.whl (516 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.3/516.3 kB 18.1 MB/s eta 0:00:00
# Downloading py_pol-1.1.3-py2.py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 8.4 MB/s eta 0:00:00
# Downloading screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 48.7 MB/s eta 0:00:00
# Installing collected packages: screeninfo, jedi, py-pol, ipympl, diffractio
# Successfully installed diffractio-0.2.4 ipympl-0.9.4 jedi-0.19.2 py-pol-1.1.3 screeninfo-0.8.1

# %%
import numpy as np
import diffractio
from diffractio import *
import torch
from torchvision.transforms import v2

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

from diffractio import degrees, mm, plt, sp, um, np, mm
from diffractio.scalar_fields_XY import Scalar_field_XY
from diffractio.utils_drawing import draw_several_fields
from diffractio.scalar_masks_XY import Scalar_mask_XY
from diffractio.scalar_sources_XY import Scalar_source_XY

# %% [markdown]
# ## Light Source

# %%
class resource:
  def __init__(self, Lambda, phase, amplitude):
    self. Lambda =  Lambda
    self.phase = phase
    self.amplitude = amplitude

# %% [markdown]
# ## Distances

# %%
class distance:
    def __init__(self,z1,z2, Dz):
        self.z1 = z1        #resource to sample distance (can be an array)
        self.z2 = z2        #sample to sensor distance   (can be an array)
        self.Dz = Dz        #distance between heights    (for multi-height phase retreival approach)

# %% [markdown]
# ## Free Space

# %%
class free_space:
    def __init__(self,  Lambda, numX, numY, z, flag):

        self. Lambda =  Lambda     #source wavelength
        self.numX = numX           #number of samples in fx range (with respect to the shape of data)
        self.numY = numY           #number of samples in fy range (with respect to the shape of data)
        self.z = z                 #distance of propagation
        self.flag = flag           #flag for forward or backward propagation (1: backward, -1:forward)

    def transfer(self):

          fx = np.array(np.linspace(-1/self.Lambda, 1/self.Lambda, self.numX))
          fy = np.array(np.linspace(-1/self.Lambda, 1/self.Lambda, self.numY))
          grid_x, grid_y = np.meshgrid(fx, fy)
          mask = grid_x** 2 +  grid_y** 2 > 1 / self.Lambda**2
          grid_x[mask] = 0
          grid_y[mask] = 0
          fz = np.sqrt((1/(self.Lambda**2))*np.ones(grid_x.shape) - grid_x**2 - grid_y**2)
          H  = np.exp(1j*2*np.pi*self.flag*self.z*fz)
          H[mask] = 0
          return H

# %% [markdown]
# ## Back Propagation

# %%
def Back_Propagation(z, Lambda, hologram, H):

  return np.fft.ifft2(np.fft.ifftshift(H*np.fft.fftshift(np.fft.fft2(hologram))))

# %% [markdown]
# ## Forward Propagation

# %%
def Forward_Propagation(z,  Lambda, hologram, H):

  return np.fft.ifft2(np.fft.ifftshift(H*np.fft.fftshift(np.fft.fft2(hologram))))

# %%
def amplitude_update(w1, w2, hologram, frame):
  '''
  weighed sum of measured hologram and calculated hologram with propagation

  '''
  return w1*hologram + w2*frame

# %%
def iterative(level, z,  Lambda, hologram, w1, w2, E, treshold):

  '''
  level : number of different measured height
  z: the distance
  Lambda: wavelength(s) of the source
  hologram : matrix of measured holograms
  w1: weight for measured hologram in amplitude update
  w2: weight for calculated hologram in amplitude update
  E: error threshold
  treshold: treshold of the number of iterations

  '''

  numX, numY = hologram[0, :, :].shape
  s1 = free_space(Lambda, numX, numY, z, -1)
  Hf = s1.transfer()

  s2 = free_space(Lambda, numX, numY, z, 1)
  Hb = s2.transfer()

  frame = hologram[0, :, :]
  phase = 0
  error = 1000
  ERROR = []
  while(treshold > 0):  #np.abs(error) > E and
    for i in range(level):
      for f in Lambda:
         F = Forward_Propagation(z, f, frame, Hf)
         hologram[i, :, :] = np.abs(F)
         frame = amplitude_update(w1, w2, hologram[i+1, :, :], np.abs(F))*np.exp(1j*np.angle(F))


    for i in range(level, 0, -1):
      for f in Lambda:
         B = Back_Propagation(z, f, frame, Hb)
         frame = amplitude_update(w1, w2, hologram[i-1, :, :], np.abs(B))*np.exp(1j*np.angle(B))


    error = np.mean(np.abs(phase - np.angle(frame)))
    ERROR.append(np.abs(error))
    phase = np.angle(frame)

    treshold -= 1

  return phase, frame, ERROR, 200-treshold

# %% [markdown]
# ## Sample

# %%
num_pixels = 512

length = 100 * um
x0 = np.linspace(-length / 2, length / 2, num_pixels)
y0 = np.linspace(-length / 2, length / 2, num_pixels)
wavelength = 0.6238 * um

u1 = Scalar_source_XY(x=x0, y=y0, wavelength=wavelength)
u1.plane_wave(A=1, theta=0 * degrees, phi=0 * degrees)

t1 = Scalar_mask_XY(x=x0, y=y0, wavelength=wavelength)
t1.circle(
    r0=(0 * um, 0 * um), radius=(25 * um, 25 * um), angle=0 * degrees)

u2 = u1 * t1

u3 = u2.RS(z=2 * mm, new_field=True)

#u4 = u2.RS(z=500 * um, new_field=True)

draw_several_fields((u2, u3), titles=('mask', '2 mm'), logarithm=True)

# %%
hologram = np.zeros((2, 512, 512))
hologram[1, :, :] = np.abs(u3.u)
hologram[0, :, :] = np.ones((512, 512))

phase, frame, ERROR, flag = iterative(1, 0.002,  np.array([6.238*1e-7]), hologram, 1, 0, 0.0005, 200)

# %%
plt.plot(ERROR)

# %%
plt.subplot(1, 2, 1)
plt.imshow(np.angle(frame))

plt.subplot(1, 2, 2)
plt.imshow(np.abs(frame))

# %%
a = Scalar_source_XY(x=x0, y=y0, wavelength=wavelength)
a.u = frame

draw_several_fields((a, u3), titles=('image', 'hologram'), logarithm=True)

# %% [markdown]
# ## Super Resolution

# %%
seq = 9   #number of digitally shifted LR samples
step = 2  #pixels to shift
scale = 5 #down sampling factor
h, w = img.shape

angle = [0, 30, 60, 90, 120, 180]
for t in angle:
  transforms = v2.compose([
      v2.RandomAffine(degrees = 0, translate = (step, step)),
      v2.GaussianBlur(5, sigma=np.sqrt(2)),
      v2.Resize((h/scale, w/scale)),
      v2.RandomRotation(t),

      v2.RandomHorizontalFlip(p=0.5),
      v2.RandomVerticalFlip(p=0.5)


   ])
